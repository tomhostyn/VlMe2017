# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.matplotlib.style.use('ggplot')

# %%
hour = pd.Timedelta ('1 hours')
hours = 2 * hour
day = pd.Timedelta ('1 days')
ts = pd.Timestamp('2012-05-01')

print (ts)
print (ts + hour)
print (ts + day)
print (hours)
# Out:
# 2012-05-01 00:00:00
# 2012-05-01 01:00:00
# 2012-05-02 00:00:00
# 0 days 02:00:00
# array([[ 1.54942082, -1.68694176, -0.56614718, -2.39785423],
#        [-0.70368843, -0.06571315, -0.73916398, -0.99927595],
#        [-0.4346359 , -0.33106971,  0.02943791,  0.06893255],
#        ...,
#        [ 0.74482358, -1.12175464, -0.67730505, -0.92335323],
#        [ 0.86408063, -0.68345422,  0.187657  , -1.48183207],
#        [ 0.65848878, -1.06106495,  0.51663397,  0.97392979]])

# %%
time= pd.date_range(ts, periods=n)
l = np.array([range(0, n), range (n, 2*n)]).T
df = pd.DataFrame(l, index=time, columns=[ 'v', 'w'])
df.plot()
plt.show()

# %%
df.iloc[5,1] = np.nan
df.plot()
plt.show()
